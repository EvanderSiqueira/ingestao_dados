# %% [markdown]
# # Limpeza e tratamento dos dados

# %% [markdown]
# ## 1 Importando csv como dataframe

# %% [markdown]
# Carregando bibliotecas necessárias

# %%
import pandas as pd
import numpy as np

# caminho para salvamento dos arquivos
caminho = '/dbfs/mnt/tarefa4/'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Carregando as bases brutas extraídas

# %%
df_consolidado = pd.read_csv(caminho + 'raw/df_consolidado.csv', encoding='latin1')
df_lista_inst = pd.read_csv(caminho + 'raw/df_lista_inst.csv', encoding='latin1')
df_reclamações = pd.read_csv(caminho + 'raw/df_reclamações.csv', encoding='latin1')
df_tarifas = pd.read_csv(caminho + 'raw/df_tarifas.csv', encoding='latin1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2 Data Wrangling

# %% [markdown]
# #### Limpando o ``` df_consolidado```

# %%
df_consolidado_normal = df_consolidado.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Deletando colunas desnecessárias e renomeando

# %%
# deletando colunas desnecessárias
df_consolidado_normal.drop(['Unnamed: 0'], axis=1, inplace=True)

# Listando nomes atuais
print(df_consolidado_normal.columns)

# Renomeando
novos_nomes_colunas = {'Codigo': 'codigo_grupo', 'Nome': 'descr_grupo'}
df_consolidado_normal.rename(columns=novos_nomes_colunas, inplace=True)
df_consolidado_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Index([&#39;Codigo&#39;, &#39;Nome&#39;], dtype=&#39;object&#39;)
# Out[7]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>codigo_grupo</th>
#       <th>descr_grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bancos privados</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Bancos públicos + Caixa Econômica Federal</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# removendo duplicadas
df_consolidado_normal.drop_duplicates(subset=['codigo_grupo'], inplace=True)
df_consolidado_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>codigo_grupo</th>
#       <th>descr_grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bancos privados</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Bancos públicos + Caixa Econômica Federal</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Limpando o ``` df_lista_inst```

# %%
df_lista_inst_normal = df_lista_inst.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Deletando colunas desnecessárias e renomeando

# %%
# deletando colunas desnecessárias
df_lista_inst_normal.drop(['Unnamed: 0'], axis=1, inplace=True)

# Listando nomes atuais
print(df_lista_inst_normal.columns)

# Renomeando
novos_nomes_colunas = {'Cnpj': 'cnpj', 'Nome': 'nome_instituicao', 'CodigoGrupo': 'codigo_grupo'}
df_lista_inst_normal.rename(columns=novos_nomes_colunas, inplace=True)
df_lista_inst_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Index([&#39;Cnpj&#39;, &#39;Nome&#39;, &#39;CodigoGrupo&#39;], dtype=&#39;object&#39;)
# Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cnpj</th>
#       <th>nome_instituicao</th>
#       <th>codigo_grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14388334</td>
#       <td>PARANÁ BANCO S.A.</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2801938</td>
#       <td>BANCO MORGAN STANLEY S.A.</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# removendo duplicadas
df_lista_inst_normal.drop_duplicates(subset=['cnpj'], inplace=True)
df_lista_inst_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cnpj</th>
#       <th>nome_instituicao</th>
#       <th>codigo_grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14388334</td>
#       <td>PARANÁ BANCO S.A.</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2801938</td>
#       <td>BANCO MORGAN STANLEY S.A.</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Limpando o ``` df_reclamações```

# %%
df_reclamações_normal = df_reclamações.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Criando chave ``` fk_calendario```

# %%
df_reclamações_normal['fk_calendario'] = df_reclamações_normal['Ano'].map(str) + df_reclamações_normal['Trimestre'].str.replace('º', '')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Deletando colunas desnecessárias e renomeando

# %%
# deletando colunas desnecessárias
df_reclamações_normal.drop(['Ano', 'Trimestre', 'Unnamed: 14', 'Unnamed: 0', 'Instituição financeira', 'Índice', 'Categoria', 'Tipo'], axis=1, inplace=True)

# Renomeando
novos_nomes_colunas = {
    'CNPJ IF': 'fk_cnpj', 
    'Quantidade de reclamações reguladas procedentes': 'quantidade_reclamacoes_reguladas_procedentes', 
    'Quantidade de reclamações reguladas - outras': 'quantidade_reclamacoes_reguladas_outras',
    'Quantidade de reclamações não reguladas': 'quantidade_reclamacoes_nao_reguladas',
    'Quantidade total de reclamações': 'quantidade_total_reclamacoes',
    'Quantidade total de clientes  CCS e SCR': 'quantidade_total_clientes_ccs_e_scr',
    'Quantidade de clientes  CCS': 'quantidade_clientes_ccs',
    'Quantidade de clientes  SCR': 'quantidade_clientes_scr'
    }

df_reclamações_normal.rename(columns=novos_nomes_colunas, inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Mantendo apenas linhas com CNPJ

# %%
# Substituindo vazios por NaN
df_reclamações_normal.fk_cnpj.replace(" ", float("NaN"), inplace=True)

# Deletando NaN
df_reclamações_normal.dropna(subset = ['fk_cnpj'], inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# removendo duplicadas
df_reclamações_normal.drop_duplicates(subset=['fk_cnpj'], inplace=True)
df_reclamações_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fk_cnpj</th>
#       <th>quantidade_reclamacoes_reguladas_procedentes</th>
#       <th>quantidade_reclamacoes_reguladas_outras</th>
#       <th>quantidade_reclamacoes_nao_reguladas</th>
#       <th>quantidade_total_reclamacoes</th>
#       <th>quantidade_total_clientes_ccs_e_scr</th>
#       <th>quantidade_clientes_ccs</th>
#       <th>quantidade_clientes_scr</th>
#       <th>fk_calendario</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>36321990</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>370789</td>
#       <td>134</td>
#       <td>370655</td>
#       <td>20201</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>27214112</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>7735</td>
#       <td>19</td>
#       <td>7724</td>
#       <td>20201</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Limpando o ``` df_tarifas```

# %%
df_tarifas_normal = df_tarifas.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# deletando colunas desnecessárias
df_tarifas_normal.drop(['Unnamed: 0'], axis=1, inplace=True)

# Listando nomes atuais
print(df_tarifas_normal.columns)

# Renomeando
novos_nomes_colunas = {
    'CodigoServico': 'pk_tarifa',
    'CNPJ':'fk_cnpj',
    'Servico': 'descr_tarifa', 
    'Unidade': 'tipo_tarifa',
    'DataVigencia': 'data_vigencia',
    'ValorMaximo': 'valor_maximo',
    'TipoValor': 'tipo_valor',
    'Periodicidade': 'periodicidade'
    }
df_tarifas_normal.rename(columns=novos_nomes_colunas, inplace=True)
df_tarifas_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Index([&#39;CodigoServico&#39;, &#39;Servico&#39;, &#39;Unidade&#39;, &#39;DataVigencia&#39;, &#39;ValorMaximo&#39;,
#        &#39;TipoValor&#39;, &#39;Periodicidade&#39;, &#39;CNPJ&#39;],
#       dtype=&#39;object&#39;)
# Out[18]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_tarifa</th>
#       <th>descr_tarifa</th>
#       <th>tipo_tarifa</th>
#       <th>data_vigencia</th>
#       <th>valor_maximo</th>
#       <th>tipo_valor</th>
#       <th>periodicidade</th>
#       <th>fk_cnpj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1101</td>
#       <td>Confecção de cadastro para início de relaciona...</td>
#       <td>Por cliente</td>
#       <td>2008-11-07</td>
#       <td>500.0</td>
#       <td>Real</td>
#       <td>Por evento</td>
#       <td>14388334</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1206</td>
#       <td>CHEQUE - Cheque Administrativo</td>
#       <td>Por Cheque</td>
#       <td>2008-04-30</td>
#       <td>30.0</td>
#       <td>Real</td>
#       <td>Por evento</td>
#       <td>14388334</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Criando chave ``` fk_calendario```

# %%
# Garantindo data_vigencia como data
df_tarifas_normal['data_vigencia'] = df_tarifas_normal['data_vigencia'].astype('datetime64[ns]')

# Criando chave
df_tarifas_normal['fk_calendario'] = df_tarifas_normal.data_vigencia.dt.year.map(str) + df_tarifas_normal.data_vigencia.dt.quarter.map(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# removendo duplicadas
df_tarifas_normal.drop_duplicates(subset=['pk_tarifa'], inplace=True)
df_tarifas_normal.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_tarifa</th>
#       <th>descr_tarifa</th>
#       <th>tipo_tarifa</th>
#       <th>data_vigencia</th>
#       <th>valor_maximo</th>
#       <th>tipo_valor</th>
#       <th>periodicidade</th>
#       <th>fk_cnpj</th>
#       <th>fk_calendario</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1101</td>
#       <td>Confecção de cadastro para início de relaciona...</td>
#       <td>Por cliente</td>
#       <td>2008-11-07</td>
#       <td>500.0</td>
#       <td>Real</td>
#       <td>Por evento</td>
#       <td>14388334</td>
#       <td>20084</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1206</td>
#       <td>CHEQUE - Cheque Administrativo</td>
#       <td>Por Cheque</td>
#       <td>2008-04-30</td>
#       <td>30.0</td>
#       <td>Real</td>
#       <td>Por evento</td>
#       <td>14388334</td>
#       <td>20082</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 3 Salvando dados tratados

# %%
# refazendo cópias

df_consolidado = df_consolidado_normal.copy()
df_lista_inst = df_lista_inst_normal.copy()
df_reclamações = df_reclamações_normal.copy()
df_tarifas = df_tarifas_normal.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_tarifas.to_csv(caminho + 'trusted/df_tarifas.csv', encoding='latin1', index=False)
df_lista_inst.to_csv(caminho + 'trusted/df_lista_inst.csv', encoding='latin1', index=False)
df_consolidado.to_csv(caminho + 'trusted/df_consolidado.csv', encoding='latin1', index=False)
df_reclamações.to_csv(caminho + 'trusted/df_reclamações.csv', encoding='latin1', index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
