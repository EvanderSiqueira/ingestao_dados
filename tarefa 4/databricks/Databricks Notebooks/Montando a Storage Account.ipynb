# %%
#montando o container da storage account

dbutils.fs.mount(
  source = "wasbs://tarefa4@ingestaodados.blob.core.windows.net",
  mount_point = "/mnt/tarefa4",
  extra_configs = {"fs.azure.account.key.ingestaodados.blob.core.windows.net":"DCQ9aF1Kf2Ui6wlXNsSl5jGwqPSgaJn2wJ+hWQTRCtfaX7Fa1fbU9TJy3Q+qtfT2w+rsffqreTgv+AStXfH7DQ=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# ...

# %%
#montando o container da storage account

dbutils.fs.mount(
  source = "wasbs://tarefa5@ingestaodados.blob.core.windows.net",
  mount_point = "/mnt/tarefa5",
  extra_configs = {"fs.azure.account.key.ingestaodados.blob.core.windows.net":"DCQ9aF1Kf2Ui6wlXNsSl5jGwqPSgaJn2wJ+hWQTRCtfaX7Fa1fbU9TJy3Q+qtfT2w+rsffqreTgv+AStXfH7DQ=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>
